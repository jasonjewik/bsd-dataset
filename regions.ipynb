# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fname = './data/chirps-v2.0.1981.days_p25.nc'

# %%
from bsd_dataset.common.visualizations import show_map

# %%
from bsd_dataset.regions import SouthAmerica
show_map(fname, day=1, region=SouthAmerica.as180())

# %%
from bsd_dataset.regions import CentralAmerica
show_map(fname, day=1, region=CentralAmerica.as180())

# %%
from bsd_dataset.regions import NorthAmerica
show_map(fname, day=1, region=NorthAmerica.as180())

# %%
from bsd_dataset.regions import Europe
show_map(fname, day=1, region=Europe.as180())

# %%
from bsd_dataset.regions import Africa
show_map(fname, day=1, region=Africa.as180())

# %%
from bsd_dataset.regions import SouthAsia
show_map(fname, day=1, region=SouthAsia.as180())

# %%
from bsd_dataset.regions import EastAsia
show_map(fname, day=1, region=EastAsia.as180())

# %%
from bsd_dataset.regions import CentralAsia
show_map(fname, day=1, region=CentralAsia.as180())

# %%
from bsd_dataset.regions import Australasia
show_map(fname, day=1, region=Australasia.as180())

# %%
from bsd_dataset.regions import Mediterranean
show_map(fname, day=1, region=Mediterranean.as180())

# %%
from bsd_dataset.regions import MENA
show_map(fname, day=1, region=MENA.as180())

# %%
from bsd_dataset.regions import SoutheastAsia
show_map(fname, day=1, region=SoutheastAsia.as180())
